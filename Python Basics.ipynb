# %% [markdown]
# # Intro to Python
# This notebook has some basic Python commands.

# %%
name = 'Gisele'
age = 39
awesome = True

# %%
print(name)
# Out:
# Gisele

# %%
def bouncer(age):
    if(age >= 21):
        return "You can drink"
    if(age >= 18):
        return "You can dance"
    return "Get out!"

# %%
bouncer(16)
# Out:
# 'Get out!'

# %%
bouncer(19)
# Out:
# 'You can dance'

# %%
bouncer(39)
# Out:
# 'You can drink'

# %%
for i in range(0,10):
    print('Python is cool!😎')
# Out:
# Python is cool!😎
# Python is cool!😎
# Python is cool!😎
# Python is cool!😎
# Python is cool!😎
# Python is cool!😎
# Python is cool!😎
# Python is cool!😎
# Python is cool!😎
# Python is cool!😎

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
data = pd.DataFrame(np.random.randn(100,4), columns=['A', 'B', 'C', 'D'])

# %%
data.head()
# Out:
#           A         B         C         D
# 0  2.420357  0.508098 -1.275086 -0.548696
# 1 -0.722493 -1.639307  1.627802 -0.571327
# 2  1.545120  0.991143  2.114665  0.240118
# 3  1.551234  1.632496 -0.357135  0.697383
# 4 -0.584156 -0.861280 -2.536616  1.161339

# %%
plt.scatter(data['A'], data['D'])

# %%
sns.pairplot(data)
